# %%
import os
import numpy as np
import pandas as pd

# %%
file_path = r"C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\1_Input\03_Stock3YRollingData"
output_path = r"C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only"

# %%
def list_and_sort_csv_files(file_path):
    csv_files = []
    
    # Loop through all files in the directory
    for filename in os.listdir(file_path):
        if filename.endswith(".csv"):
            # Try to split the filename and check if the first part is numeric
            try:
                # If the first part (before underscore) is not a valid integer, skip it
                int(filename.split('_')[0])  
                csv_files.append(filename)
            except ValueError:
                print(f"Skipping invalid file: {filename}")
                continue  # Skip files that do not start with a valid number
    
    # Sort the valid files by the numeric part before the underscore
    sorted_files = sorted(csv_files, key=lambda x: int(x.split('_')[0]))
    
    return sorted_files

# %%
def CleanData(file_path):
    # Import CSV file
    data = pd.read_csv(file_path)
    
    # Convert 'Date' to datetime and set it as index
    data["Date"] = pd.to_datetime(data["Date"], format='mixed').dt.date
    data.set_index("Date", inplace=True)
    
    # Sort by the 'Date' index in ascending order
    data.sort_index(ascending=True, inplace=True)
    
    # Drop unnecessary columns
    data.drop(columns=["ROI", "pct_ROI", "log_return_stock", "3day_log_return_stock",
                       "Name_market", "Close_market", "%Chg", "TRI", "log_return_market", 
                       "volatility_market", "3day_log_return_market", "TimeSeries_Beta"], inplace=True)
    
    # Ensure 'Date' index is datetime for resampling
    data.index = pd.to_datetime(data.index)
    
    # Get the last trading day of each month
    last_trading_days = data.resample('M').last()
    
    # Add 'Month_Year' column with period format (YYYY-MM)
    last_trading_days['Month_Year'] = last_trading_days.index.to_period('M')
    
    
    # Reset index and set 'Month_Year' as new index
    last_trading_days.reset_index(drop=True, inplace=True)
    last_trading_days.set_index("Month_Year", inplace=True)
    
    # Drop rows with NaN in '5year_rolling_correlation' (renamed to '3year_rolling_correlation')
    last_trading_days.dropna(subset=['3year_rolling_correlation'], inplace=True)
    

    # Display the result
    print(last_trading_days.head(5))
    
    return last_trading_days

# %%
def process_all_files(file_path):
    # Get the sorted list of .xlsx files
    sorted_csv_files = list_and_sort_csv_files(file_path)
    
    # Process each file
    for filename in sorted_csv_files:
        file_paths = os.path.join(file_path, filename)
        print(f'Processing file: {filename}')
        result_df = CleanData(file_paths)
        if result_df is not None:
            output_file = os.path.join(output_path,f"{os.path.splitext(filename)[0]}.csv")
            result_df.to_csv(output_file, index=True)
            print(f"DataFrame saved to {output_file}")
        else:
            print(f"Error processing file: {filename}")

# %%
# Call the function to process all files in the directory
process_all_files(file_path)
# Out:
# Processing file: 1_AAV.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2015-06           AAV         4.18           0.02405
# 2015-07           AAV         4.64           0.02246
# 2015-08           AAV         4.13           0.02398
# 2015-09           AAV         4.11           0.02126
# 2015-10           AAV         4.39           0.02003
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2015-06                       0.52606       1.418932
# 2015-07                       0.51593       1.362974
# 2015-08                       0.52777       1.230805
# 2015-09                       0.52688       1.136939
# 2015-10                       0.53834       1.105537
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\1_AAV.csv
# Processing file: 2_ACE.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2022-11           ACE         2.70           0.01252
# 2022-12           ACE         2.70           0.01200
# 2023-01           ACE         2.58           0.01126
# 2023-02           ACE         2.48           0.01133
# 2023-03           ACE         2.28           0.01624
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2022-11                       0.50997       0.968382
# 2022-12                       0.51798       1.016439
# 2023-01                       0.52058       1.021385
# 2023-02                       0.56318       1.092314
# 2023-03                       0.52279       1.183702
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\2_ACE.csv
# Processing file: 4_ADVANC.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01        ADVANC        151.0           0.01892
# 2012-02        ADVANC        160.0           0.01799
# 2012-03        ADVANC        184.0           0.01577
# 2012-04        ADVANC        183.0           0.01547
# 2012-05        ADVANC        179.0           0.01551
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.44272       0.709087
# 2012-02                       0.44082       0.710791
# 2012-03                       0.45107       0.814774
# 2012-04                       0.47356       0.910521
# 2012-05                       0.49177       0.910760
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\4_ADVANC.csv
# Processing file: 5_AEONTS.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01        AEONTS        30.00           0.01444
# 2012-02        AEONTS        29.25           0.01401
# 2012-03        AEONTS        29.75           0.01290
# 2012-04        AEONTS        30.50           0.01386
# 2012-05        AEONTS        30.00           0.01632
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.34463       0.583633
# 2012-02                       0.35235       0.593459
# 2012-03                       0.35664       0.668260
# 2012-04                       0.34962       0.737682
# 2012-05                       0.28505       0.711519
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\5_AEONTS.csv
# Processing file: 6_AJ.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01            AJ        16.56           0.03786
# 2012-02            AJ        15.96           0.03717
# 2012-03            AJ        15.57           0.02549
# 2012-04            AJ        15.07           0.02234
# 2012-05            AJ        12.27           0.02062
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.37585       0.925080
# 2012-02                       0.37458       0.945649
# 2012-03                       0.36768       0.946482
# 2012-04                       0.37601       0.985370
# 2012-05                       0.39843       0.950154
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\6_AJ.csv
# Processing file: 7_AMATA.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01         AMATA        15.08           0.03818
# 2012-02         AMATA        16.56           0.03772
# 2012-03         AMATA        16.56           0.02512
# 2012-04         AMATA        17.76           0.02161
# 2012-05         AMATA        16.07           0.02191
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.70363       1.391313
# 2012-02                       0.70242       1.438352
# 2012-03                       0.69788       1.422201
# 2012-04                       0.69725       1.450005
# 2012-05                       0.71047       1.442393
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\7_AMATA.csv
# Processing file: 8_ANAN.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2015-12          ANAN         4.17           0.02035
# 2016-01          ANAN         3.46           0.02119
# 2016-02          ANAN         3.34           0.02028
# 2016-03          ANAN         3.40           0.01952
# 2016-04          ANAN         3.64           0.02113
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2015-12                       0.57310       1.119913
# 2016-01                       0.55518       1.056610
# 2016-02                       0.55235       1.126594
# 2016-03                       0.54069       1.075834
# 2016-04                       0.52984       1.104860
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\8_ANAN.csv
# Processing file: 9_AOT.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01           AOT         5.28           0.02687
# 2012-02           AOT         5.28           0.02514
# 2012-03           AOT         5.82           0.02025
# 2012-04           AOT         6.20           0.02050
# 2012-05           AOT         5.65           0.01801
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.63836       1.032942
# 2012-02                       0.63666       1.027262
# 2012-03                       0.63530       1.150136
# 2012-04                       0.63613       1.308757
# 2012-05                       0.62487       1.153610
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\9_AOT.csv
# Processing file: 10_AP.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01            AP         4.77           0.02547
# 2012-02            AP         5.18           0.02478
# 2012-03            AP         5.55           0.02041
# 2012-04            AP         6.23           0.01673
# 2012-05            AP         6.27           0.01868
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.60643       0.969955
# 2012-02                       0.60521       0.987738
# 2012-03                       0.60548       1.120574
# 2012-04                       0.60688       1.107533
# 2012-05                       0.60204       1.153088
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\10_AP.csv
# Processing file: 12_ASP.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01           ASP         2.50           0.03574
# 2012-02           ASP         2.50           0.03590
# 2012-03           ASP         2.44           0.02863
# 2012-04           ASP         2.44           0.02371
# 2012-05           ASP         2.22           0.02430
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.70388       1.328290
# 2012-02                       0.70971       1.398508
# 2012-03                       0.71000       1.585265
# 2012-04                       0.70849       1.570613
# 2012-05                       0.69362       1.528681
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\12_ASP.csv
# Processing file: 13_AURA.csv
# Empty DataFrame
# Columns: [Name_stock, Close_stock, volatility_stock, 3year_rolling_correlation, Adjusted_Beta]
# Index: []
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\13_AURA.csv
# Processing file: 14_AWC.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2022-10           AWC         6.10           0.01391
# 2022-11           AWC         6.30           0.01509
# 2022-12           AWC         6.30           0.01554
# 2023-01           AWC         5.95           0.01657
# 2023-02           AWC         5.90           0.01664
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2022-10                       0.71283       1.198561
# 2022-11                       0.72522       1.374205
# 2022-12                       0.73093       1.526478
# 2023-01                       0.73126       1.684485
# 2023-02                       0.72655       1.711732
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\14_AWC.csv
# Processing file: 15_BA.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2017-11            BA         17.9           0.01052
# 2017-12            BA         17.1           0.01064
# 2018-01            BA         14.5           0.01080
# 2018-02            BA         14.9           0.01224
# 2018-03            BA         14.4           0.01318
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2017-11                       0.37617       0.950901
# 2017-12                       0.38302       0.962115
# 2018-01                       0.35231       0.879615
# 2018-02                       0.36426       0.926599
# 2018-03                       0.36821       0.934276
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\15_BA.csv
# Processing file: 16_BAM.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2022-12           BAM         15.8           0.01627
# 2023-01           BAM         15.9           0.01612
# 2023-02           BAM         14.8           0.01589
# 2023-03           BAM         13.6           0.01671
# 2023-04           BAM         13.2           0.01546
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2022-12                       0.65760       1.461073
# 2023-01                       0.67477       1.553070
# 2023-02                       0.69669       1.601129
# 2023-03                       0.61656       1.351020
# 2023-04                       0.59056       1.218839
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\16_BAM.csv
# Processing file: 17_BANPU.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01         BANPU        37.55           0.02415
# 2012-02         BANPU        41.24           0.02342
# 2012-03         BANPU        38.69           0.01758
# 2012-04         BANPU        35.38           0.01554
# 2012-05         BANPU        28.64           0.01631
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.74522       1.064098
# 2012-02                       0.73580       1.075340
# 2012-03                       0.72899       1.147268
# 2012-04                       0.73200       1.192702
# 2012-05                       0.72901       1.196216
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\17_BANPU.csv
# Processing file: 18_BAY.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01           BAY        22.20           0.02789
# 2012-02           BAY        25.25           0.02809
# 2012-03           BAY        27.00           0.02330
# 2012-04           BAY        27.75           0.02021
# 2012-05           BAY        28.25           0.01962
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.77129       1.193774
# 2012-02                       0.76277       1.239695
# 2012-03                       0.76389       1.437821
# 2012-04                       0.76087       1.471581
# 2012-05                       0.75235       1.388467
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\18_BAY.csv
# Processing file: 19_BBL.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01           BBL        153.5           0.02201
# 2012-02           BBL        181.0           0.02103
# 2012-03           BBL        185.0           0.01644
# 2012-04           BBL        191.0           0.01440
# 2012-05           BBL        180.0           0.01511
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.77543       1.029787
# 2012-02                       0.77256       1.036719
# 2012-03                       0.77235       1.140375
# 2012-04                       0.76938       1.172061
# 2012-05                       0.78033       1.189562
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\19_BBL.csv
# Processing file: 20_BCH.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01           BCH         5.80           0.01844
# 2012-02           BCH         5.60           0.01709
# 2012-03           BCH         6.08           0.01659
# 2012-04           BCH         6.80           0.01616
# 2012-05           BCH         7.80           0.01714
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.33385       0.627166
# 2012-02                       0.32679       0.618870
# 2012-03                       0.33333       0.722446
# 2012-04                       0.33500       0.777254
# 2012-05                       0.32095       0.768376
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\20_BCH.csv
# Processing file: 21_BCP.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01           BCP         20.4           0.02492
# 2012-02           BCP         23.5           0.02483
# 2012-03           BCP         23.7           0.01743
# 2012-04           BCP         25.5           0.01701
# 2012-05           BCP         22.7           0.01738
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.63056       0.979836
# 2012-02                       0.62798       1.011081
# 2012-03                       0.63713       1.047532
# 2012-04                       0.64204       1.161052
# 2012-05                       0.65307       1.160069
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\21_BCP.csv
# Processing file: 22_BCPG.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2019-09          BCPG        17.95           0.01920
# 2019-10          BCPG        17.76           0.01930
# 2019-11          BCPG        16.77           0.01964
# 2019-12          BCPG        15.98           0.01678
# 2020-01          BCPG        15.68           0.01695
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2019-09                       0.57701       1.504179
# 2019-10                       0.57381       1.438237
# 2019-11                       0.58401       1.455517
# 2019-12                       0.58443       1.291521
# 2020-01                       0.59564       1.206612
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\22_BCPG.csv
# Processing file: 23_BDMS.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01          BDMS         7.68           0.01885
# 2012-02          BDMS         7.52           0.01810
# 2012-03          BDMS         8.68           0.01538
# 2012-04          BDMS         9.20           0.01689
# 2012-05          BDMS         8.95           0.01619
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.33024       0.629706
# 2012-02                       0.31538       0.623712
# 2012-03                       0.30804       0.676248
# 2012-04                       0.30885       0.763518
# 2012-05                       0.31619       0.742798
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\23_BDMS.csv
# Processing file: 24_BEAUTY.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2015-12        BEAUTY         5.75           0.02167
# 2016-01        BEAUTY         5.20           0.02290
# 2016-02        BEAUTY         5.40           0.02280
# 2016-03        BEAUTY         5.40           0.02386
# 2016-04        BEAUTY         5.55           0.02408
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2015-12                       0.45568       1.009542
# 2016-01                       0.46961       1.000227
# 2016-02                       0.48588       1.118577
# 2016-03                       0.46424       1.109291
# 2016-04                       0.43939       1.066139
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\24_BEAUTY.csv
# Processing file: 25_BEC.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01           BEC        43.25           0.02996
# 2012-02           BEC        44.25           0.02923
# 2012-03           BEC        51.00           0.02466
# 2012-04           BEC        51.50           0.02151
# 2012-05           BEC        54.00           0.02160
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.46566       0.914803
# 2012-02                       0.46418       0.931730
# 2012-03                       0.46112       1.063045
# 2012-04                       0.46722       1.100342
# 2012-05                       0.47205       1.082787
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\25_BEC.csv
# Processing file: 26_BECL.csv
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01          BECL         18.7           0.00993
# 2012-02          BECL         19.5           0.00975
# 2012-03          BECL         21.6           0.00927
# 2012-04          BECL         23.4           0.00925
# 2012-05          BECL         23.2           0.01150
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.46547       0.570558
# 2012-02                       0.46003       0.575779
# 2012-03                       0.46378       0.650685
# 2012-04                       0.46097       0.697141
# 2012-05                       0.44377       0.741743
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\26_BECL.csv
# Processing file: 27_BEM.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2019-01           BEM         10.4           0.01579
# 2019-02           BEM         10.6           0.01555
# 2019-03           BEM         10.1           0.01458
# 2019-04           BEM         10.9           0.01489
# 2019-05           BEM         11.3           0.01502
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2019-01                       0.44132       0.936034
# 2019-02                       0.44865       0.937343
# 2019-03                       0.46165       0.947224
# 2019-04                       0.47175       1.090920
# 2019-05                       0.46899       1.111538
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\27_BEM.csv
# Processing file: 28_BGC.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2021-10           BGC         11.3           0.02030
# 2021-11           BGC         10.3           0.01974
# 2021-12           BGC         10.6           0.01969
# 2022-01           BGC         10.5           0.01519
# 2022-02           BGC         10.2           0.01309
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2021-10                       0.45284       1.186818
# 2021-11                       0.46007       1.220643
# 2021-12                       0.45556       1.169955
# 2022-01                       0.45664       1.039296
# 2022-02                       0.45439       0.954158
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\28_BGC.csv
# Processing file: 30_BGRIM.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2020-07         BGRIM        49.00           0.04108
# 2020-08         BGRIM        46.25           0.03793
# 2020-09         BGRIM        42.25           0.02637
# 2020-10         BGRIM        39.25           0.02341
# 2020-11         BGRIM        49.00           0.02287
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2020-07                       0.58931       0.996767
# 2020-08                       0.59035       0.979353
# 2020-09                       0.59512       1.128228
# 2020-10                       0.60316       1.237153
# 2020-11                       0.61400       1.149583
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\30_BGRIM.csv
# Processing file: 31_BH.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01            BH        47.25           0.02480
# 2012-02            BH        45.75           0.02463
# 2012-03            BH        53.50           0.02022
# 2012-04            BH        61.00           0.02108
# 2012-05            BH        63.00           0.01902
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.43820       0.801010
# 2012-02                       0.43426       0.819170
# 2012-03                       0.42628       0.902588
# 2012-04                       0.42403       1.022896
# 2012-05                       0.38696       0.892856
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\31_BH.csv
# Processing file: 32_BIG.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2015-03           BIG         1.01           0.03581
# 2015-04           BIG         1.14           0.03976
# 2015-05           BIG         1.27           0.04240
# 2015-06           BIG         1.14           0.04291
# 2015-07           BIG         1.13           0.04383
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2015-03                       0.06924       0.581426
# 2015-04                       0.08408       0.643129
# 2015-05                       0.07545       0.629051
# 2015-06                       0.07968       0.675361
# 2015-07                       0.08576       0.712371
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\32_BIG.csv
# Processing file: 33_BIGC.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01          BIGC        117.0           0.02761
# 2012-02          BIGC        153.5           0.02933
# 2012-03          BIGC        164.0           0.02726
# 2012-04          BIGC        190.0           0.02267
# 2012-05          BIGC        216.0           0.02765
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.38561       0.792867
# 2012-02                       0.36965       0.824892
# 2012-03                       0.36268       0.976481
# 2012-04                       0.38243       1.004159
# 2012-05                       0.41351       1.165640
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\33_BIGC.csv
# Processing file: 34_BJC.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01           BJC        26.87           0.02083
# 2012-02           BJC        31.20           0.02260
# 2012-03           BJC        37.58           0.02259
# 2012-04           BJC        38.94           0.02231
# 2012-05           BJC        35.53           0.02323
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.25426       0.595433
# 2012-02                       0.25826       0.628740
# 2012-03                       0.24859       0.727443
# 2012-04                       0.25866       0.802140
# 2012-05                       0.27781       0.832156
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\34_BJC.csv
# Processing file: 35_BJCHI.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2016-12         BJCHI         5.10           0.02148
# 2017-01         BJCHI         5.15           0.02062
# 2017-02         BJCHI         4.92           0.02033
# 2017-03         BJCHI         4.76           0.01935
# 2017-04         BJCHI         4.68           0.01506
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2016-12                       0.51933       1.130691
# 2017-01                       0.50254       1.094684
# 2017-02                       0.51732       1.125318
# 2017-03                       0.51859       1.209251
# 2017-04                       0.52064       1.398833
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\35_BJCHI.csv
# Processing file: 36_BLA.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-09           BLA        31.43           0.01669
# 2012-10           BLA        30.18           0.01470
# 2012-11           BLA        36.07           0.01291
# 2012-12           BLA        44.47           0.01540
# 2013-01           BLA        49.82           0.01649
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-09                       0.44220       0.874619
# 2012-10                       0.43841       0.848062
# 2012-11                       0.44015       0.921315
# 2012-12                       0.45955       1.079399
# 2013-01                       0.46522       1.220479
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\36_BLA.csv
# Processing file: 37_BLAND.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01         BLAND         0.71           0.02523
# 2012-02         BLAND         0.71           0.02371
# 2012-03         BLAND         0.68           0.02036
# 2012-04         BLAND         0.72           0.01804
# 2012-05         BLAND         0.67           0.01585
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.56968       0.930370
# 2012-02                       0.56825       0.928016
# 2012-03                       0.56704       1.073174
# 2012-04                       0.56372       1.108677
# 2012-05                       0.54413       0.977531
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\37_BLAND.csv
# Processing file: 38_BLS.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01           BLS         21.9           0.02967
# 2012-02           BLS         21.9           0.02898
# 2012-03           BLS         21.9           0.02640
# 2012-04           BLS         22.0           0.02875
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.66390       1.126860
# 2012-02                       0.66268       1.152624
# 2012-03                       0.65406       1.406833
# 2012-04                       0.65171       1.506496
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\38_BLS.csv
# Processing file: 39_BMCL.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01          BMCL         0.60           0.01965
# 2012-02          BMCL         0.61           0.01940
# 2012-03          BMCL         0.60           0.01646
# 2012-04          BMCL         0.64           0.01694
# 2012-05          BMCL         0.59           0.01782
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.42335       0.706968
# 2012-02                       0.57112       0.834215
# 2012-03                       0.62232       0.997282
# 2012-04                       0.62533       1.138194
# 2012-05                       0.61334       1.131901
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\39_BMCL.csv
# Processing file: 40_BPP.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2019-10           BPP         17.4           0.01515
# 2019-11           BPP         17.6           0.01447
# 2019-12           BPP         17.7           0.01333
# 2020-01           BPP         14.8           0.01425
# 2020-02           BPP         11.6           0.01871
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2019-10                       0.53640       1.161856
# 2019-11                       0.54474       1.125373
# 2019-12                       0.55090       1.067591
# 2020-01                       0.57467       1.054251
# 2020-02                       0.63217       1.109674
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\40_BPP.csv
# Processing file: 41_BTG.csv
# Empty DataFrame
# Columns: [Name_stock, Close_stock, volatility_stock, 3year_rolling_correlation, Adjusted_Beta]
# Index: []
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\41_BTG.csv
# Processing file: 42_BTS.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01           BTS         4.31           0.02207
# 2012-02           BTS         4.62           0.02209
# 2012-03           BTS         4.88           0.01783
# 2012-04           BTS         5.25           0.01583
# 2012-05           BTS         4.81           0.01587
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.47689       0.788375
# 2012-02                       0.51378       0.844784
# 2012-03                       0.53589       0.957138
# 2012-04                       0.53112       0.985898
# 2012-05                       0.51280       0.944964
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\42_BTS.csv
# Processing file: 43_BYD.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01           BYD          0.0           0.08461
# 2012-02           BYD          0.0           0.09302
# 2012-03           BYD          0.0           0.08958
# 2012-04           BYD          0.0           0.08026
# 2012-05           BYD          0.0           0.07779
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.15308       0.877937
# 2012-02                       0.14750       0.937705
# 2012-03                       0.14811       1.173626
# 2012-04                       0.13739       1.168427
# 2012-05                       0.11234       0.985196
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\43_BYD.csv
# Processing file: 44_CBG.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2017-11           CBG        83.25           0.02314
# 2017-12           CBG        80.75           0.02387
# 2018-01           CBG        82.50           0.02394
# 2018-02           CBG        66.00           0.02951
# 2018-03           CBG        63.75           0.02854
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2017-11                       0.36301       1.569381
# 2017-12                       0.34095       1.522548
# 2018-01                       0.34806       1.450322
# 2018-02                       0.34375       1.598118
# 2018-03                       0.35745       1.523114
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\44_CBG.csv
# Processing file: 45_CCET.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01          CCET         1.88           0.02109
# 2012-02          CCET         2.03           0.02025
# 2012-03          CCET         2.01           0.01355
# 2012-04          CCET         2.07           0.01277
# 2012-05          CCET         1.86           0.01327
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.47901       0.772779
# 2012-02                       0.48341       0.783634
# 2012-03                       0.49090       0.787854
# 2012-04                       0.49789       0.843070
# 2012-05                       0.48577       0.831663
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\45_CCET.csv
# Processing file: 46_CENTEL.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01        CENTEL         11.5           0.03133
# 2012-02        CENTEL         11.6           0.02702
# 2012-03        CENTEL         12.9           0.01977
# 2012-04        CENTEL         12.7           0.02075
# 2012-05        CENTEL         12.4           0.02050
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.47918       0.953975
# 2012-02                       0.47625       0.904309
# 2012-03                       0.47691       0.949767
# 2012-04                       0.49278       1.112556
# 2012-05                       0.51650       1.109035
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\46_CENTEL.csv
# Processing file: 47_CGS.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01           CGS         0.92           0.02017
# 2012-02           CGS         0.93           0.02109
# 2012-03           CGS         1.02           0.01739
# 2012-04           CGS         0.82           0.01753
# 2012-05           CGS         0.79           0.01658
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.32619       0.642777
# 2012-02                       0.32968       0.672487
# 2012-03                       0.32891       0.733513
# 2012-04                       0.40527       0.895079
# 2012-05                       0.43628       0.884388
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\47_CGS.csv
# Processing file: 48_CHG.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2016-05           CHG         2.90           0.02540
# 2016-06           CHG         3.10           0.02634
# 2016-07           CHG         3.16           0.02298
# 2016-08           CHG         2.60           0.02301
# ...
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01            TU        15.65           0.01975
# 2012-02            TU        16.29           0.01781
# 2012-03            TU        16.65           0.01615
# 2012-04            TU        18.19           0.01672
# 2012-05            TU        16.81           0.01796
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.36700       0.667463
# 2012-02                       0.36642       0.655752
# 2012-03                       0.37483       0.752974
# 2012-04                       0.37710       0.839381
# 2012-05                       0.38368       0.861444
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\233_TU.csv
# Processing file: 235_TVO.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01           TVO        17.64           0.02356
# 2012-02           TVO        18.09           0.02273
# 2012-03           TVO        18.18           0.01606
# 2012-04           TVO        21.18           0.01673
# 2012-05           TVO        18.73           0.01809
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.56440       0.890674
# 2012-02                       0.56453       0.902878
# 2012-03                       0.55993       0.924343
# 2012-04                       0.55024       1.041499
# 2012-05                       0.54965       1.065837
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\235_TVO.csv
# Processing file: 236_TWZ.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01           TWZ         0.28           0.03577
# 2012-02           TWZ         0.34           0.03063
# 2012-03           TWZ         0.35           0.02556
# 2012-04           TWZ         0.37           0.02395
# 2012-05           TWZ         0.34           0.02355
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.32326       0.826679
# 2012-02                       0.33621       0.803584
# 2012-03                       0.33782       0.903480
# 2012-04                       0.33656       0.961715
# 2012-05                       0.33425       0.927115
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\236_TWZ.csv
# Processing file: 240_UNIQ.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01          UNIQ         2.07           0.02416
# 2012-02          UNIQ         1.92           0.02356
# 2012-03          UNIQ         1.91           0.01786
# 2012-04          UNIQ         1.87           0.01546
# 2012-05          UNIQ         1.68           0.01253
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.39345       0.750766
# 2012-02                       0.39095       0.760971
# 2012-03                       0.38384       0.799731
# 2012-04                       0.38737       0.817334
# 2012-05                       0.39050       0.727654
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\240_UNIQ.csv
# Processing file: 241_UV.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01            UV         1.99           0.02422
# 2012-02            UV         2.06           0.02105
# 2012-03            UV         2.06           0.01618
# 2012-04            UV         2.12           0.01544
# 2012-05            UV         1.99           0.01528
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.50463       0.851001
# 2012-02                       0.50084       0.813168
# 2012-03                       0.49964       0.871380
# 2012-04                       0.50028       0.938280
# 2012-05                       0.52152       0.933627
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\241_UV.csv
# Processing file: 242_UVAN.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01          UVAN         8.80           0.00903
# 2012-02          UVAN        10.55           0.01070
# 2012-03          UVAN        10.10           0.00964
# 2012-04          UVAN        10.60           0.00991
# 2012-05          UVAN         9.60           0.01135
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.40320       0.534350
# 2012-02                       0.39060       0.563792
# 2012-03                       0.40637       0.628420
# 2012-04                       0.40093       0.676879
# 2012-05                       0.39307       0.698751
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\242_UVAN.csv
# Processing file: 243_VGI.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2015-10           VGI         3.55           0.02239
# 2015-11           VGI         3.67           0.02274
# 2015-12           VGI         3.55           0.02214
# 2016-01           VGI         3.69           0.02115
# 2016-02           VGI         4.17           0.01894
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2015-10                       0.53254       1.180168
# 2015-11                       0.55363       1.235589
# 2015-12                       0.55359       1.156573
# 2016-01                       0.55803       1.058735
# 2016-02                       0.55748       1.084887
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\243_VGI.csv
# Processing file: 244_VIBHA.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01         VIBHA         0.46           0.02125
# 2012-02         VIBHA         0.46           0.01989
# 2012-03         VIBHA         0.59           0.01958
# 2012-04         VIBHA         0.61           0.01768
# 2012-05         VIBHA         0.55           0.01812
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.28288       0.621815
# 2012-02                       0.28173       0.619606
# 2012-03                       0.27940       0.718988
# 2012-04                       0.28405       0.749965
# 2012-05                       0.29206       0.754384
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\244_VIBHA.csv
# Processing file: 245_VNG.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01           VNG         3.60           0.02111
# 2012-02           VNG         3.58           0.02008
# 2012-03           VNG         3.47           0.01741
# 2012-04           VNG         3.43           0.01678
# 2012-05           VNG         3.30           0.01131
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.51595       0.801908
# 2012-02                       0.52240       0.811096
# 2012-03                       0.51859       0.926452
# 2012-04                       0.51498       1.002186
# 2012-05                       0.50602       0.783242
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\245_VNG.csv
# Processing file: 246_WHA.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2015-11           WHA         2.94           0.02120
# 2015-12           WHA         2.86           0.02345
# 2016-01           WHA         2.68           0.02373
# 2016-02           WHA         2.88           0.02144
# 2016-03           WHA         3.12           0.02273
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2015-11                       0.50171       1.105946
# 2015-12                       0.51411       1.144190
# 2016-01                       0.51925       1.087729
# 2016-02                       0.53618       1.145667
# 2016-03                       0.51689       1.152331
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\246_WHA.csv
# Processing file: 247_WHAUP.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2020-04         WHAUP         4.72           0.02739
# 2020-05         WHAUP         4.60           0.02692
# 2020-06         WHAUP         4.52           0.02712
# 2020-07         WHAUP         4.40           0.02602
# 2020-08         WHAUP         4.06           0.02466
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2020-04                       0.57598       0.802109
# 2020-05                       0.57143       0.787478
# 2020-06                       0.58520       0.791063
# 2020-07                       0.59423       0.781147
# 2020-08                       0.59319       0.778475
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\247_WHAUP.csv
# Processing file: 248_WORK.csv
#            Name_stock  Close_stock  volatility_stock  \
# Month_Year
# 2012-01          WORK         9.93           0.01973
# 2012-02          WORK        10.29           0.01772
# 2012-03          WORK        14.64           0.02119
# 2012-04          WORK        22.14           0.02943
# 2012-05          WORK        21.25           0.03720
#
#             3year_rolling_correlation  Adjusted_Beta
# Month_Year
# 2012-01                       0.33501       0.643902
# 2012-02                       0.33690       0.633960
# 2012-03                       0.33047       0.808318
# 2012-04                       0.30502       1.025557
# 2012-05                       0.31056       1.173627
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\248_WORK.csv
# Processing file: 249_TRUE.csv
# Empty DataFrame
# Columns: [Name_stock, Close_stock, volatility_stock, 3year_rolling_correlation, Adjusted_Beta]
# Index: []
# DataFrame saved to C:\Users\Kantinant Sukkert\Desktop\BAC Thematic\2_Output\03_Stock_3YStat_Only\249_TRUE.csv
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
# C:\Users\Kantinant Sukkert\AppData\Local\Temp\ipykernel_2876\126927409.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   last_trading_days = data.resample('M').last()
